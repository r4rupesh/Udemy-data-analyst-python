# %%
import pandas as pd

# %%
data = pd.read_excel("customer_data1.xlsx")

# %%
#loc mehthods 
first_3_rows= data.loc[0:2,["Income"]]

# %%
first_3_rows
# Out:
#     Income
# 0  72504.0
# 1  40881.0
# 2  63333.0

# %%
#iloc mehthods 
first_three_rows= data.iloc[0:3,0:3]

# %%
first_three_rows
# Out:
#   CustomerID  Gender  Age
# 0       C001    Male   49
# 1       C002  Female   38
# 2       C003    Male   17
