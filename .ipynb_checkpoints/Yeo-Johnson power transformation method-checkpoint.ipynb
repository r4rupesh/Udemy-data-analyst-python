# %%
import numpy as np
import pandas as pd
import seaborn as sns
from scipy.stats import yeojohnson
from scipy.stats import shapiro

# %%
data =pd.read_excel("customer_data.xlsx")
data.head(1)
# Out:
#   CustomerID Gender  Age   Income     City     Region  Frequency_of_Purchases  \
# 0       C001   Male   49  72504.0  Chicago  Northeast                      10
#
#    Average_Purchase_Amount Customer_Lifespan_Months Purchase_Channel  \
# 0                   98.241                        3           Online
#
#   Date_of_Purchase Churn_Status
# 0       2022-03-05          Yes

# %%
def yeojohnson_transformation(data,column_name):
    transformed_data,_=yeojohnson(data[column_name])
    data[f"{column_name}_yeojohnson"]=transformed_data
    stat,p_value =shapiro(data[f"{column_name}_yeojohnson"])
    kdeplot =sns.kdeplot(data[f"{column_name}_yeojohnson"])
    print(kdeplot)
    print("P value: ",p_value)

# %%
yeojohnson_transformation(data,"Age")
# Out:
# Axes(0.125,0.11;0.775x0.77)
# P value:  0.07805942020718619

# %%
data.head(1)
# Out:
#   CustomerID Gender  Age   Income     City     Region  Frequency_of_Purchases  \
# 0       C001   Male   49  72504.0  Chicago  Northeast                      10
#
#    Average_Purchase_Amount Customer_Lifespan_Months Purchase_Channel  \
# 0                   98.241                        3           Online
#
#   Date_of_Purchase Churn_Status  Age_yeojohnson
# 0       2022-03-05          Yes       12.984335
