# %%
import pandas as pd

# %%
data= pd.read_excel("customer+performance+additional.xlsx")

# %%
numeric_data = data.select_dtypes(include=['number']).columns

# %%
numeric_data
# Out:
# Index(['Age', 'Income', 'Frequency_of_Purchases', 'Average_Purchase_Amount',
#        'Recency', 'Frequency_Score', 'Monetary_Score'],
#       dtype='object')

# %%
round(data[numeric_data].corr(),3)
# Out:
#                            Age  Income  Frequency_of_Purchases  \
# Age                      1.000   0.127                   0.311
# Income                   0.127   1.000                  -0.033
# Frequency_of_Purchases   0.311  -0.033                   1.000
# Average_Purchase_Amount  0.072  -0.009                   0.050
# Recency                 -0.041   0.159                  -0.025
# Frequency_Score         -0.014   0.137                  -0.041
# Monetary_Score           0.056   0.137                  -0.044
#
#                          Average_Purchase_Amount  Recency  Frequency_Score  \
# Age                                        0.072   -0.041           -0.014
# Income                                    -0.009    0.159            0.137
# Frequency_of_Purchases                     0.050   -0.025           -0.041
# Average_Purchase_Amount                    1.000   -0.140           -0.142
# Recency                                   -0.140    1.000            0.769
# ...
