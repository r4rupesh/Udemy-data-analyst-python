# %%
import pandas as pd

# %%
data =pd.read_excel("customer_data+performance.xlsx")

# %%
data2=pd.read_excel("additional_data.xlsx")

# %%
concated_data =pd.concat([data,data2])

# %%
data.shape
# Out:
# (81, 15)

# %%
data2.shape
# Out:
# (20, 16)

# %%
concated_data.shape
# Out:
# (101, 16)

# %%
final_concat=concated_data.reset_index(drop=True)

# %%
ready_to_dump=final_concat.drop("CustomerID.1",axis=1)

# %%
ready_to_dump.to_excel("customer+performance+additional.xlsx",index=False)
