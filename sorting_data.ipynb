# %%
import pandas as pd

# %%
data =pd.read_excel("customer_data1.xlsx")

# %%
data
# Out:
#    CustomerID  Gender  Age   Income         City     Region  \
# 0        C001    Male   49  72504.0      Chicago  Northeast
# 1        C002  Female   38  40881.0     New York       West
# 2        C003    Male   17  63333.0     New York  Northeast
# 3        C004    Male   34  58030.0      Chicago    Midwest
# 4        C005    Male   30  78889.0      Houston    Midwest
# ..        ...     ...  ...      ...          ...        ...
# 75       C076    Male   44  59659.0      Houston    Midwest
# 76       C078    Male   30  76887.0      Houston    Midwest
# 77       C079  Female   42  56569.0     New York       West
# 78       C080  Female   26  43931.0  Los Angeles  Northeast
# 79       C021  Female   22  41743.0  Los Angeles  Northeast
#
#     Frequency_of_Purchases  Average_Purchase_Amount  Customer_Lifespan_Months  \
# 0                       10             9.824100e+01                         3
# 1                       15             1.576400e+02                         4
# ...

# %%
sort_data=data.sort_values(by="Income",ascending=True)

# %%
sort_data
# Out:
#    CustomerID  Gender  Age   Income         City     Region  \
# 50       C051  Female   19  15531.0      Houston    Midwest
# 23       C024    Male   54  27660.0     New York    Midwest
# 10       C011  Female   53  27958.0  Los Angeles    Midwest
# 49       C050  Female   39  29104.0          NaN    Midwest
# 14       C015    Male   44  32500.0     New York  Northeast
# ..        ...     ...  ...      ...          ...        ...
# 58       C059  Female   46      NaN  Los Angeles    Midwest
# 63       C064    Male   30      NaN      Houston       West
# 66       C067    Male   54      NaN      Houston       West
# 69       C070    Male   36      NaN      Chicago  Northeast
# 74       C075  Female   42      NaN  Los Angeles  Northeast
#
#     Frequency_of_Purchases  Average_Purchase_Amount  Customer_Lifespan_Months  \
# 50                      10                   97.782                         3
# 23                      12                  125.763                         3
# ...
